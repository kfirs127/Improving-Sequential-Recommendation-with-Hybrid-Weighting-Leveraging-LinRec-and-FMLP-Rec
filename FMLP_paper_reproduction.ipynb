# %% [markdown]
# <a href="https://colab.research.google.com/github/kfirs127/Improving-Sequential-Recommendation-with-Hybrid-Attention-Weighting-Leveraging-LinRec-and-FMLP-Rec/blob/main/FMLP_paper_reproduction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Reproduce FMLP-Rec

# %%
# !git clone https://github.com/RUCAIBox/FMLP-Rec.git
# Out:
# Cloning into 'FMLP-Rec'...
# remote: Enumerating objects: 20, done.
# remote: Counting objects: 100% (20/20), done.
# remote: Compressing objects: 100% (20/20), done.
# remote: Total 20 (delta 0), reused 20 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (20/20), 8.41 MiB | 11.16 MiB/s, done.

# %% [markdown]
# Running the FMLP-Rec model on the Amazon Beauty dataset (included in their files after all preprocessing).
#
# * Number of hidden layers (learnable filter blocks): 2
# * Hidden layer size: 64
# * Batch size: 256
# * Adam optimizer
# * Learning rate: 0.001
# * Early stopping implemented if MRR score decreases for more than 10 epochs

# %%
# !cd /content/FMLP-Rec/ && python main.py --data_name='Beauty'
# Out:
# Namespace(data_dir='./data/', output_dir='output/', data_name='Beauty', do_eval=False, load_model=None, model_name='FMLPRec', hidden_size=64, num_hidden_layers=2, num_attention_heads=2, hidden_act='gelu', attention_probs_dropout_prob=0.5, hidden_dropout_prob=0.5, initializer_range=0.02, max_seq_length=50, no_filters=False, lr=0.001, batch_size=256, epochs=200, no_cuda=False, log_freq=1, full_sort=False, patience=10, seed=42, weight_decay=0.0, adam_beta1=0.9, adam_beta2=0.999, gpu_id='0', variance=5, cuda_condition=True, data_file='./data/Beauty.txt', sample_file='./data/Beauty_sample.txt', item_size=12102, log_file='output/FMLPRec-Beauty-Feb-20-2025_07-59-31.txt')
# Total Parameters: 851200
# Recommendation EP_train:0: 100% 587/587 [00:16<00:00, 35.64it/s]
# {'epoch': 0, 'rec_loss': '1.2398'}
# Recommendation EP_test:0: 100% 88/88 [00:02<00:00, 39.30it/s]
# {'Epoch': 0, 'HIT@1': '0.0850', 'NDCG@1': '0.0850', 'HIT@5': '0.2497', 'NDCG@5': '0.1682', 'HIT@10': '0.3571', 'NDCG@10': '0.2029', 'MRR': '0.1758'}
# Validation score increased.  Saving model ...
# Recommendation EP_train:1: 100% 587/587 [00:14<00:00, 41.56it/s]
# {'epoch': 1, 'rec_loss': '1.1075'}
# Recommendation EP_test:1: 100% 88/88 [00:01<00:00, 54.55it/s]
# {'Epoch': 1, 'HIT@1': '0.1018', 'NDCG@1': '0.1018', 'HIT@5': '0.2933', 'NDCG@5': '0.1995', 'HIT@10': '0.4084', 'NDCG@10': '0.2367', 'MRR': '0.2031'}
# Validation score increased.  Saving model ...
# Recommendation EP_train:2: 100% 587/587 [00:12<00:00, 47.97it/s]
# {'epoch': 2, 'rec_loss': '1.0195'}
# Recommendation EP_test:2: 100% 88/88 [00:01<00:00, 56.26it/s]
# {'Epoch': 2, 'HIT@1': '0.1271', 'NDCG@1': '0.1271', 'HIT@5': '0.3323', 'NDCG@5': '0.2320', 'HIT@10': '0.4437', 'NDCG@10': '0.2680', 'MRR': '0.2321'}
# Validation score increased.  Saving model ...
# Recommendation EP_train:3: 100% 587/587 [00:12<00:00, 47.15it/s]
# {'epoch': 3, 'rec_loss': '0.9431'}
# Recommendation EP_test:3: 100% 88/88 [00:01<00:00, 66.88it/s]
# {'Epoch': 3, 'HIT@1': '0.1409', 'NDCG@1': '0.1409', 'HIT@5': '0.3530', 'NDCG@5': '0.2499', 'HIT@10': '0.4618', 'NDCG@10': '0.2851', 'MRR': '0.2482'}
# Validation score increased.  Saving model ...
# Recommendation EP_train:4: 100% 587/587 [00:12<00:00, 46.50it/s]
# {'epoch': 4, 'rec_loss': '0.8787'}
# Recommendation EP_test:4: 100% 88/88 [00:01<00:00, 65.83it/s]
# {'Epoch': 4, 'HIT@1': '0.1557', 'NDCG@1': '0.1557', 'HIT@5': '0.3709', 'NDCG@5': '0.2668', 'HIT@10': '0.4787', 'NDCG@10': '0.3016', 'MRR': '0.2641'}
# Validation score increased.  Saving model ...
# Recommendation EP_train:5: 100% 587/587 [00:12<00:00, 47.17it/s]
# {'epoch': 5, 'rec_loss': '0.8268'}
# Recommendation EP_test:5: 100% 88/88 [00:01<00:00, 67.23it/s]
# {'Epoch': 5, 'HIT@1': '0.1657', 'NDCG@1': '0.1657', 'HIT@5': '0.3799', 'NDCG@5': '0.2772', 'HIT@10': '0.4848', 'NDCG@10': '0.3112', 'MRR': '0.2744'}
# Validation score increased.  Saving model ...
# Recommendation EP_train:6: 100% 587/587 [00:12<00:00, 48.17it/s]
# {'epoch': 6, 'rec_loss': '0.7808'}
# Recommendation EP_test:6: 100% 88/88 [00:01<00:00, 68.89it/s]
# {'Epoch': 6, 'HIT@1': '0.1759', 'NDCG@1': '0.1759', 'HIT@5': '0.3890', 'NDCG@5': '0.2862', 'HIT@10': '0.4903', 'NDCG@10': '0.3190', 'MRR': '0.2829'}
# Validation score increased.  Saving model ...
# Recommendation EP_train:7: 100% 587/587 [00:12<00:00, 47.44it/s]
# {'epoch': 7, 'rec_loss': '0.7473'}
# Recommendation EP_test:7: 100% 88/88 [00:01<00:00, 56.95it/s]
# {'Epoch': 7, 'HIT@1': '0.1805', 'NDCG@1': '0.1805', 'HIT@5': '0.3894', 'NDCG@5': '0.2893', 'HIT@10': '0.4912', 'NDCG@10': '0.3222', 'MRR': '0.2868'}
# Validation score increased.  Saving model ...
# Recommendation EP_train:8: 100% 587/587 [00:12<00:00, 47.50it/s]
# {'epoch': 8, 'rec_loss': '0.7166'}
# Recommendation EP_test:8: 100% 88/88 [00:01<00:00, 57.16it/s]
# {'Epoch': 8, 'HIT@1': '0.1862', 'NDCG@1': '0.1862', 'HIT@5': '0.3909', 'NDCG@5': '0.2938', 'HIT@10': '0.4906', 'NDCG@10': '0.3259', 'MRR': '0.2919'}
# Validation score increased.  Saving model ...
# Recommendation EP_train:9: 100% 587/587 [00:12<00:00, 47.06it/s]
# {'epoch': 9, 'rec_loss': '0.6921'}
# Recommendation EP_test:9: 100% 88/88 [00:01<00:00, 67.30it/s]
# {'Epoch': 9, 'HIT@1': '0.1875', 'NDCG@1': '0.1875', 'HIT@5': '0.3960', 'NDCG@5': '0.2963', 'HIT@10': '0.4960', 'NDCG@10': '0.3286', 'MRR': '0.2936'}
# Validation score increased.  Saving model ...
# Recommendation EP_train:10: 100% 587/587 [00:12<00:00, 47.86it/s]
# {'epoch': 10, 'rec_loss': '0.6672'}
# Recommendation EP_test:10: 100% 88/88 [00:01<00:00, 59.78it/s]
# {'Epoch': 10, 'HIT@1': '0.1983', 'NDCG@1': '0.1983', 'HIT@5': '0.4013', 'NDCG@5': '0.3049', 'HIT@10': '0.4970', 'NDCG@10': '0.3357', 'MRR': '0.3027'}
# Validation score increased.  Saving model ...
# Recommendation EP_train:11: 100% 587/587 [00:12<00:00, 48.34it/s]
# {'epoch': 11, 'rec_loss': '0.6540'}
# Recommendation EP_test:11: 100% 88/88 [00:01<00:00, 65.26it/s]
# {'Epoch': 11, 'HIT@1': '0.1953', 'NDCG@1': '0.1953', 'HIT@5': '0.4041', 'NDCG@5': '0.3045', 'HIT@10': '0.4961', 'NDCG@10': '0.3341', 'MRR': '0.3009'}
# EarlyStopping counter: 1 out of 10
# Recommendation EP_train:12: 100% 587/587 [00:12<00:00, 47.83it/s]
# {'epoch': 12, 'rec_loss': '0.6347'}
# Recommendation EP_test:12: 100% 88/88 [00:01<00:00, 59.35it/s]
# {'Epoch': 12, 'HIT@1': '0.1985', 'NDCG@1': '0.1985', 'HIT@5': '0.4042', 'NDCG@5': '0.3063', 'HIT@10': '0.5034', 'NDCG@10': '0.3383', 'MRR': '0.3039'}
# Validation score increased.  Saving model ...
# Recommendation EP_train:13: 100% 587/587 [00:12<00:00, 47.72it/s]
# {'epoch': 13, 'rec_loss': '0.6204'}
# Recommendation EP_test:13: 100% 88/88 [00:01<00:00, 59.87it/s]
# {'Epoch': 13, 'HIT@1': '0.2035', 'NDCG@1': '0.2035', 'HIT@5': '0.4056', 'NDCG@5': '0.3097', 'HIT@10': '0.5025', 'NDCG@10': '0.3409', 'MRR': '0.3076'}
# Validation score increased.  Saving model ...
# Recommendation EP_train:14: 100% 587/587 [00:12<00:00, 47.31it/s]
# {'epoch': 14, 'rec_loss': '0.6105'}
# Recommendation EP_test:14: 100% 88/88 [00:01<00:00, 48.39it/s]
# {'Epoch': 14, 'HIT@1': '0.2014', 'NDCG@1': '0.2014', 'HIT@5': '0.4041', 'NDCG@5': '0.3084', 'HIT@10': '0.5053', 'NDCG@10': '0.3410', 'MRR': '0.3068'}
# EarlyStopping counter: 1 out of 10
# Recommendation EP_train:15: 100% 587/587 [00:12<00:00, 47.47it/s]
# {'epoch': 15, 'rec_loss': '0.5983'}
# Recommendation EP_test:15: 100% 88/88 [00:01<00:00, 65.29it/s]
# {'Epoch': 15, 'HIT@1': '0.2015', 'NDCG@1': '0.2015', 'HIT@5': '0.4051', 'NDCG@5': '0.3091', 'HIT@10': '0.5059', 'NDCG@10': '0.3416', 'MRR': '0.3074'}
# EarlyStopping counter: 2 out of 10
# Recommendation EP_train:16: 100% 587/587 [00:12<00:00, 48.17it/s]
# {'epoch': 16, 'rec_loss': '0.5913'}
# Recommendation EP_test:16: 100% 88/88 [00:01<00:00, 59.08it/s]
# {'Epoch': 16, 'HIT@1': '0.2044', 'NDCG@1': '0.2044', 'HIT@5': '0.4078', 'NDCG@5': '0.3118', 'HIT@10': '0.5075', 'NDCG@10': '0.3440', 'MRR': '0.3101'}
# Validation score increased.  Saving model ...
# Recommendation EP_train:17: 100% 587/587 [00:12<00:00, 47.67it/s]
# {'epoch': 17, 'rec_loss': '0.5796'}
# Recommendation EP_test:17: 100% 88/88 [00:01<00:00, 66.80it/s]
# {'Epoch': 17, 'HIT@1': '0.2086', 'NDCG@1': '0.2086', 'HIT@5': '0.4094', 'NDCG@5': '0.3143', 'HIT@10': '0.5112', 'NDCG@10': '0.3471', 'MRR': '0.3129'}
# Validation score increased.  Saving model ...
# Recommendation EP_train:18: 100% 587/587 [00:12<00:00, 47.72it/s]
# {'epoch': 18, 'rec_loss': '0.5719'}
# Recommendation EP_test:18: 100% 88/88 [00:01<00:00, 58.80it/s]
# {'Epoch': 18, 'HIT@1': '0.2063', 'NDCG@1': '0.2063', 'HIT@5': '0.4135', 'NDCG@5': '0.3155', 'HIT@10': '0.5093', 'NDCG@10': '0.3464', 'MRR': '0.3125'}
# EarlyStopping counter: 1 out of 10
# Recommendation EP_train:19: 100% 587/587 [00:12<00:00, 47.77it/s]
# {'epoch': 19, 'rec_loss': '0.5664'}
# Recommendation EP_test:19: 100% 88/88 [00:01<00:00, 57.90it/s]
# {'Epoch': 19, 'HIT@1': '0.2073', 'NDCG@1': '0.2073', 'HIT@5': '0.4159', 'NDCG@5': '0.3170', 'HIT@10': '0.5124', 'NDCG@10': '0.3481', 'MRR': '0.3137'}
# Validation score increased.  Saving model ...
# Recommendation EP_train:20: 100% 587/587 [00:12<00:00, 47.70it/s]
# {'epoch': 20, 'rec_loss': '0.5561'}
# Recommendation EP_test:20: 100% 88/88 [00:01<00:00, 50.15it/s]
# {'Epoch': 20, 'HIT@1': '0.2103', 'NDCG@1': '0.2103', 'HIT@5': '0.4156', 'NDCG@5': '0.3189', 'HIT@10': '0.5145', 'NDCG@10': '0.3506', 'MRR': '0.3164'}
# Validation score increased.  Saving model ...
# Recommendation EP_train:21: 100% 587/587 [00:12<00:00, 47.76it/s]
# {'epoch': 21, 'rec_loss': '0.5483'}
# Recommendation EP_test:21: 100% 88/88 [00:01<00:00, 67.49it/s]
# {'Epoch': 21, 'HIT@1': '0.2109', 'NDCG@1': '0.2109', 'HIT@5': '0.4156', 'NDCG@5': '0.3188', 'HIT@10': '0.5133', 'NDCG@10': '0.3504', 'MRR': '0.3164'}
# Validation score increased.  Saving model ...
# Recommendation EP_train:22: 100% 587/587 [00:12<00:00, 48.08it/s]
# {'epoch': 22, 'rec_loss': '0.5495'}
# Recommendation EP_test:22: 100% 88/88 [00:01<00:00, 59.23it/s]
# {'Epoch': 22, 'HIT@1': '0.2114', 'NDCG@1': '0.2114', 'HIT@5': '0.4157', 'NDCG@5': '0.3188', 'HIT@10': '0.5131', 'NDCG@10': '0.3503', 'MRR': '0.3163'}
# EarlyStopping counter: 1 out of 10
# Recommendation EP_train:23: 100% 587/587 [00:12<00:00, 47.95it/s]
# {'epoch': 23, 'rec_loss': '0.5445'}
# Recommendation EP_test:23: 100% 88/88 [00:01<00:00, 67.30it/s]
# {'Epoch': 23, 'HIT@1': '0.2130', 'NDCG@1': '0.2130', 'HIT@5': '0.4171', 'NDCG@5': '0.3204', 'HIT@10': '0.5143', 'NDCG@10': '0.3517', 'MRR': '0.3178'}
# Validation score increased.  Saving model ...
# Recommendation EP_train:24: 100% 587/587 [00:12<00:00, 48.32it/s]
# {'epoch': 24, 'rec_loss': '0.5353'}
# Recommendation EP_test:24: 100% 88/88 [00:01<00:00, 62.20it/s]
# {'Epoch': 24, 'HIT@1': '0.2138', 'NDCG@1': '0.2138', 'HIT@5': '0.4164', 'NDCG@5': '0.3209', 'HIT@10': '0.5150', 'NDCG@10': '0.3527', 'MRR': '0.3189'}
# Validation score increased.  Saving model ...
# Recommendation EP_train:25: 100% 587/587 [00:12<00:00, 47.83it/s]
# {'epoch': 25, 'rec_loss': '0.5322'}
# Recommendation EP_test:25: 100% 88/88 [00:01<00:00, 54.26it/s]
# {'Epoch': 25, 'HIT@1': '0.2160', 'NDCG@1': '0.2160', 'HIT@5': '0.4208', 'NDCG@5': '0.3241', 'HIT@10': '0.5159', 'NDCG@10': '0.3549', 'MRR': '0.3214'}
# Validation score increased.  Saving model ...
# Recommendation EP_train:26: 100% 587/587 [00:12<00:00, 47.26it/s]
# {'epoch': 26, 'rec_loss': '0.5302'}
# Recommendation EP_test:26: 100% 88/88 [00:01<00:00, 58.49it/s]
# {'Epoch': 26, 'HIT@1': '0.2126', 'NDCG@1': '0.2126', 'HIT@5': '0.4209', 'NDCG@5': '0.3222', 'HIT@10': '0.5178', 'NDCG@10': '0.3534', 'MRR': '0.3188'}
# EarlyStopping counter: 1 out of 10
# Recommendation EP_train:27: 100% 587/587 [00:12<00:00, 47.93it/s]
# {'epoch': 27, 'rec_loss': '0.5288'}
# Recommendation EP_test:27: 100% 88/88 [00:01<00:00, 66.41it/s]
# {'Epoch': 27, 'HIT@1': '0.2128', 'NDCG@1': '0.2128', 'HIT@5': '0.4168', 'NDCG@5': '0.3205', 'HIT@10': '0.5121', 'NDCG@10': '0.3513', 'MRR': '0.3181'}
# EarlyStopping counter: 2 out of 10
# Recommendation EP_train:28: 100% 587/587 [00:12<00:00, 48.10it/s]
# {'epoch': 28, 'rec_loss': '0.5181'}
# Recommendation EP_test:28: 100% 88/88 [00:01<00:00, 59.37it/s]
# {'Epoch': 28, 'HIT@1': '0.2150', 'NDCG@1': '0.2150', 'HIT@5': '0.4239', 'NDCG@5': '0.3251', 'HIT@10': '0.5177', 'NDCG@10': '0.3554', 'MRR': '0.3215'}
# Validation score increased.  Saving model ...
# Recommendation EP_train:29: 100% 587/587 [00:12<00:00, 48.28it/s]
# {'epoch': 29, 'rec_loss': '0.5148'}
# Recommendation EP_test:29: 100% 88/88 [00:01<00:00, 67.24it/s]
# {'Epoch': 29, 'HIT@1': '0.2158', 'NDCG@1': '0.2158', 'HIT@5': '0.4218', 'NDCG@5': '0.3243', 'HIT@10': '0.5203', 'NDCG@10': '0.3560', 'MRR': '0.3216'}
# Validation score increased.  Saving model ...
# Recommendation EP_train:30: 100% 587/587 [00:12<00:00, 48.47it/s]
# {'epoch': 30, 'rec_loss': '0.5113'}
# Recommendation EP_test:30: 100% 88/88 [00:01<00:00, 60.07it/s]
# {'Epoch': 30, 'HIT@1': '0.2163', 'NDCG@1': '0.2163', 'HIT@5': '0.4228', 'NDCG@5': '0.3247', 'HIT@10': '0.5207', 'NDCG@10': '0.3562', 'MRR': '0.3216'}
# Validation score increased.  Saving model ...
# Recommendation EP_train:31: 100% 587/587 [00:12<00:00, 48.26it/s]
# {'epoch': 31, 'rec_loss': '0.5069'}
# Recommendation EP_test:31: 100% 88/88 [00:01<00:00, 45.20it/s]
# {'Epoch': 31, 'HIT@1': '0.2180', 'NDCG@1': '0.2180', 'HIT@5': '0.4207', 'NDCG@5': '0.3249', 'HIT@10': '0.5205', 'NDCG@10': '0.3572', 'MRR': '0.3228'}
# Validation score increased.  Saving model ...
# Recommendation EP_train:32: 100% 587/587 [00:12<00:00, 47.84it/s]
# {'epoch': 32, 'rec_loss': '0.5077'}
# Recommendation EP_test:32: 100% 88/88 [00:01<00:00, 60.44it/s]
# {'Epoch': 32, 'HIT@1': '0.2194', 'NDCG@1': '0.2194', 'HIT@5': '0.4233', 'NDCG@5': '0.3265', 'HIT@10': '0.5200', 'NDCG@10': '0.3577', 'MRR': '0.3238'}
# Validation score increased.  Saving model ...
# Recommendation EP_train:33: 100% 587/587 [00:12<00:00, 47.82it/s]
# {'epoch': 33, 'rec_loss': '0.4987'}
# Recommendation EP_test:33: 100% 88/88 [00:01<00:00, 66.27it/s]
# {'Epoch': 33, 'HIT@1': '0.2161', 'NDCG@1': '0.2161', 'HIT@5': '0.4223', 'NDCG@5': '0.3249', 'HIT@10': '0.5183', 'NDCG@10': '0.3559', 'MRR': '0.3220'}
# EarlyStopping counter: 1 out of 10
# Recommendation EP_train:34: 100% 587/587 [00:12<00:00, 47.90it/s]
# {'epoch': 34, 'rec_loss': '0.4982'}
# Recommendation EP_test:34: 100% 88/88 [00:01<00:00, 59.00it/s]
# {'Epoch': 34, 'HIT@1': '0.2185', 'NDCG@1': '0.2185', 'HIT@5': '0.4281', 'NDCG@5': '0.3292', 'HIT@10': '0.5224', 'NDCG@10': '0.3597', 'MRR': '0.3255'}
# Validation score increased.  Saving model ...
# Recommendation EP_train:35: 100% 587/587 [00:12<00:00, 48.15it/s]
# {'epoch': 35, 'rec_loss': '0.4972'}
# Recommendation EP_test:35: 100% 88/88 [00:01<00:00, 68.96it/s]
# {'Epoch': 35, 'HIT@1': '0.2176', 'NDCG@1': '0.2176', 'HIT@5': '0.4222', 'NDCG@5': '0.3253', 'HIT@10': '0.5223', 'NDCG@10': '0.3577', 'MRR': '0.3231'}
# EarlyStopping counter: 1 out of 10
# Recommendation EP_train:36: 100% 587/587 [00:12<00:00, 47.96it/s]
# {'epoch': 36, 'rec_loss': '0.4955'}
# Recommendation EP_test:36: 100% 88/88 [00:01<00:00, 52.77it/s]
# {'Epoch': 36, 'HIT@1': '0.2169', 'NDCG@1': '0.2169', 'HIT@5': '0.4245', 'NDCG@5': '0.3267', 'HIT@10': '0.5243', 'NDCG@10': '0.3590', 'MRR': '0.3239'}
# EarlyStopping counter: 2 out of 10
# Recommendation EP_train:37: 100% 587/587 [00:12<00:00, 47.56it/s]
# {'epoch': 37, 'rec_loss': '0.4890'}
# Recommendation EP_test:37: 100% 88/88 [00:01<00:00, 59.20it/s]
# {'Epoch': 37, 'HIT@1': '0.2157', 'NDCG@1': '0.2157', 'HIT@5': '0.4267', 'NDCG@5': '0.3269', 'HIT@10': '0.5229', 'NDCG@10': '0.3579', 'MRR': '0.3231'}
# EarlyStopping counter: 3 out of 10
# Recommendation EP_train:38: 100% 587/587 [00:12<00:00, 47.72it/s]
# {'epoch': 38, 'rec_loss': '0.4896'}
# Recommendation EP_test:38: 100% 88/88 [00:01<00:00, 58.70it/s]
# {'Epoch': 38, 'HIT@1': '0.2175', 'NDCG@1': '0.2175', 'HIT@5': '0.4273', 'NDCG@5': '0.3281', 'HIT@10': '0.5241', 'NDCG@10': '0.3593', 'MRR': '0.3244'}
# EarlyStopping counter: 4 out of 10
# Recommendation EP_train:39: 100% 587/587 [00:12<00:00, 47.85it/s]
# {'epoch': 39, 'rec_loss': '0.4855'}
# Recommendation EP_test:39: 100% 88/88 [00:01<00:00, 65.88it/s]
# {'Epoch': 39, 'HIT@1': '0.2185', 'NDCG@1': '0.2185', 'HIT@5': '0.4279', 'NDCG@5': '0.3293', 'HIT@10': '0.5242', 'NDCG@10': '0.3604', 'MRR': '0.3257'}
# Validation score increased.  Saving model ...
# Recommendation EP_train:40: 100% 587/587 [00:12<00:00, 48.10it/s]
# {'epoch': 40, 'rec_loss': '0.4881'}
# Recommendation EP_test:40: 100% 88/88 [00:01<00:00, 60.95it/s]
# {'Epoch': 40, 'HIT@1': '0.2198', 'NDCG@1': '0.2198', 'HIT@5': '0.4274', 'NDCG@5': '0.3301', 'HIT@10': '0.5261', 'NDCG@10': '0.3620', 'MRR': '0.3272'}
# Validation score increased.  Saving model ...
# Recommendation EP_train:41: 100% 587/587 [00:12<00:00, 48.03it/s]
# {'epoch': 41, 'rec_loss': '0.4822'}
# Recommendation EP_test:41: 100% 88/88 [00:01<00:00, 67.49it/s]
# {'Epoch': 41, 'HIT@1': '0.2197', 'NDCG@1': '0.2197', 'HIT@5': '0.4270', 'NDCG@5': '0.3293', 'HIT@10': '0.5230', 'NDCG@10': '0.3604', 'MRR': '0.3261'}
# EarlyStopping counter: 1 out of 10
# Recommendation EP_train:42: 100% 587/587 [00:12<00:00, 47.96it/s]
# {'epoch': 42, 'rec_loss': '0.4816'}
# Recommendation EP_test:42: 100% 88/88 [00:02<00:00, 42.86it/s]
# {'Epoch': 42, 'HIT@1': '0.2188', 'NDCG@1': '0.2188', 'HIT@5': '0.4307', 'NDCG@5': '0.3308', 'HIT@10': '0.5277', 'NDCG@10': '0.3621', 'MRR': '0.3267'}
# EarlyStopping counter: 2 out of 10
# Recommendation EP_train:43: 100% 587/587 [00:12<00:00, 48.31it/s]
# {'epoch': 43, 'rec_loss': '0.4788'}
# Recommendation EP_test:43: 100% 88/88 [00:01<00:00, 66.62it/s]
# {'Epoch': 43, 'HIT@1': '0.2211', 'NDCG@1': '0.2211', 'HIT@5': '0.4274', 'NDCG@5': '0.3303', 'HIT@10': '0.5261', 'NDCG@10': '0.3621', 'MRR': '0.3273'}
# Validation score increased.  Saving model ...
# Recommendation EP_train:44: 100% 587/587 [00:12<00:00, 47.73it/s]
# {'epoch': 44, 'rec_loss': '0.4776'}
# Recommendation EP_test:44: 100% 88/88 [00:01<00:00, 58.76it/s]
# {'Epoch': 44, 'HIT@1': '0.2245', 'NDCG@1': '0.2245', 'HIT@5': '0.4279', 'NDCG@5': '0.3318', 'HIT@10': '0.5260', 'NDCG@10': '0.3635', 'MRR': '0.3293'}
# Validation score increased.  Saving model ...
# Recommendation EP_train:45: 100% 587/587 [00:12<00:00, 48.06it/s]
# {'epoch': 45, 'rec_loss': '0.4728'}
# Recommendation EP_test:45: 100% 88/88 [00:01<00:00, 67.32it/s]
# {'Epoch': 45, 'HIT@1': '0.2227', 'NDCG@1': '0.2227', 'HIT@5': '0.4306', 'NDCG@5': '0.3325', 'HIT@10': '0.5273', 'NDCG@10': '0.3638', 'MRR': '0.3291'}
# EarlyStopping counter: 1 out of 10
# Recommendation EP_train:46: 100% 587/587 [00:12<00:00, 47.77it/s]
# {'epoch': 46, 'rec_loss': '0.4718'}
# Recommendation EP_test:46: 100% 88/88 [00:01<00:00, 59.72it/s]
# {'Epoch': 46, 'HIT@1': '0.2224', 'NDCG@1': '0.2224', 'HIT@5': '0.4299', 'NDCG@5': '0.3319', 'HIT@10': '0.5244', 'NDCG@10': '0.3623', 'MRR': '0.3283'}
# EarlyStopping counter: 2 out of 10
# Recommendation EP_train:47: 100% 587/587 [00:12<00:00, 48.46it/s]
# {'epoch': 47, 'rec_loss': '0.4703'}
# Recommendation EP_test:47: 100% 88/88 [00:01<00:00, 67.24it/s]
# {'Epoch': 47, 'HIT@1': '0.2213', 'NDCG@1': '0.2213', 'HIT@5': '0.4276', 'NDCG@5': '0.3306', 'HIT@10': '0.5262', 'NDCG@10': '0.3623', 'MRR': '0.3277'}
# EarlyStopping counter: 3 out of 10
# Recommendation EP_train:48: 100% 587/587 [00:12<00:00, 47.67it/s]
# {'epoch': 48, 'rec_loss': '0.4721'}
# Recommendation EP_test:48: 100% 88/88 [00:01<00:00, 47.03it/s]
# {'Epoch': 48, 'HIT@1': '0.2232', 'NDCG@1': '0.2232', 'HIT@5': '0.4318', 'NDCG@5': '0.3332', 'HIT@10': '0.5256', 'NDCG@10': '0.3635', 'MRR': '0.3294'}
# Validation score increased.  Saving model ...
# Recommendation EP_train:49: 100% 587/587 [00:12<00:00, 48.15it/s]
# {'epoch': 49, 'rec_loss': '0.4679'}
# Recommendation EP_test:49: 100% 88/88 [00:01<00:00, 66.43it/s]
# {'Epoch': 49, 'HIT@1': '0.2237', 'NDCG@1': '0.2237', 'HIT@5': '0.4284', 'NDCG@5': '0.3316', 'HIT@10': '0.5263', 'NDCG@10': '0.3631', 'MRR': '0.3288'}
# EarlyStopping counter: 1 out of 10
# Recommendation EP_train:50: 100% 587/587 [00:12<00:00, 48.21it/s]
# {'epoch': 50, 'rec_loss': '0.4644'}
# Recommendation EP_test:50: 100% 88/88 [00:01<00:00, 59.68it/s]
# {'Epoch': 50, 'HIT@1': '0.2233', 'NDCG@1': '0.2233', 'HIT@5': '0.4287', 'NDCG@5': '0.3316', 'HIT@10': '0.5268', 'NDCG@10': '0.3632', 'MRR': '0.3289'}
# EarlyStopping counter: 2 out of 10
# Recommendation EP_train:51: 100% 587/587 [00:12<00:00, 48.27it/s]
# {'epoch': 51, 'rec_loss': '0.4673'}
# Recommendation EP_test:51: 100% 88/88 [00:01<00:00, 66.12it/s]
# {'Epoch': 51, 'HIT@1': '0.2206', 'NDCG@1': '0.2206', 'HIT@5': '0.4252', 'NDCG@5': '0.3287', 'HIT@10': '0.5230', 'NDCG@10': '0.3602', 'MRR': '0.3262'}
# EarlyStopping counter: 3 out of 10
# Recommendation EP_train:52: 100% 587/587 [00:12<00:00, 48.03it/s]
# {'epoch': 52, 'rec_loss': '0.4605'}
# Recommendation EP_test:52: 100% 88/88 [00:01<00:00, 59.52it/s]
# {'Epoch': 52, 'HIT@1': '0.2236', 'NDCG@1': '0.2236', 'HIT@5': '0.4291', 'NDCG@5': '0.3316', 'HIT@10': '0.5301', 'NDCG@10': '0.3641', 'MRR': '0.3288'}
# EarlyStopping counter: 4 out of 10
# Recommendation EP_train:53: 100% 587/587 [00:12<00:00, 47.88it/s]
# {'epoch': 53, 'rec_loss': '0.4629'}
# Recommendation EP_test:53: 100% 88/88 [00:01<00:00, 55.66it/s]
# {'Epoch': 53, 'HIT@1': '0.2234', 'NDCG@1': '0.2234', 'HIT@5': '0.4295', 'NDCG@5': '0.3324', 'HIT@10': '0.5261', 'NDCG@10': '0.3636', 'MRR': '0.3295'}
# Validation score increased.  Saving model ...
# Recommendation EP_train:54: 100% 587/587 [00:12<00:00, 47.62it/s]
# {'epoch': 54, 'rec_loss': '0.4597'}
# Recommendation EP_test:54: 100% 88/88 [00:01<00:00, 56.67it/s]
# {'Epoch': 54, 'HIT@1': '0.2238', 'NDCG@1': '0.2238', 'HIT@5': '0.4312', 'NDCG@5': '0.3337', 'HIT@10': '0.5304', 'NDCG@10': '0.3657', 'MRR': '0.3307'}
# Validation score increased.  Saving model ...
# Recommendation EP_train:55: 100% 587/587 [00:12<00:00, 48.21it/s]
# {'epoch': 55, 'rec_loss': '0.4591'}
# Recommendation EP_test:55: 100% 88/88 [00:01<00:00, 67.54it/s]
# {'Epoch': 55, 'HIT@1': '0.2243', 'NDCG@1': '0.2243', 'HIT@5': '0.4324', 'NDCG@5': '0.3346', 'HIT@10': '0.5302', 'NDCG@10': '0.3662', 'MRR': '0.3314'}
# Validation score increased.  Saving model ...
# Recommendation EP_train:56: 100% 587/587 [00:12<00:00, 47.91it/s]
# {'epoch': 56, 'rec_loss': '0.4565'}
# Recommendation EP_test:56: 100% 88/88 [00:01<00:00, 59.93it/s]
# {'Epoch': 56, 'HIT@1': '0.2210', 'NDCG@1': '0.2210', 'HIT@5': '0.4312', 'NDCG@5': '0.3321', 'HIT@10': '0.5279', 'NDCG@10': '0.3633', 'MRR': '0.3284'}
# EarlyStopping counter: 1 out of 10
# Recommendation EP_train:57: 100% 587/587 [00:12<00:00, 47.81it/s]
# {'epoch': 57, 'rec_loss': '0.4584'}
# Recommendation EP_test:57: 100% 88/88 [00:01<00:00, 67.13it/s]
# {'Epoch': 57, 'HIT@1': '0.2213', 'NDCG@1': '0.2213', 'HIT@5': '0.4315', 'NDCG@5': '0.3328', 'HIT@10': '0.5306', 'NDCG@10': '0.3647', 'MRR': '0.3293'}
# EarlyStopping counter: 2 out of 10
# Recommendation EP_train:58: 100% 587/587 [00:12<00:00, 48.13it/s]
# {'epoch': 58, 'rec_loss': '0.4550'}
# Recommendation EP_test:58: 100% 88/88 [00:01<00:00, 60.59it/s]
# {'Epoch': 58, 'HIT@1': '0.2221', 'NDCG@1': '0.2221', 'HIT@5': '0.4343', 'NDCG@5': '0.3342', 'HIT@10': '0.5316', 'NDCG@10': '0.3656', 'MRR': '0.3300'}
# EarlyStopping counter: 3 out of 10
# Recommendation EP_train:59: 100% 587/587 [00:12<00:00, 48.12it/s]
# {'epoch': 59, 'rec_loss': '0.4529'}
# Recommendation EP_test:59: 100% 88/88 [00:01<00:00, 47.40it/s]
# {'Epoch': 59, 'HIT@1': '0.2253', 'NDCG@1': '0.2253', 'HIT@5': '0.4318', 'NDCG@5': '0.3344', 'HIT@10': '0.5299', 'NDCG@10': '0.3661', 'MRR': '0.3313'}
# EarlyStopping counter: 4 out of 10
# Recommendation EP_train:60: 100% 587/587 [00:12<00:00, 47.88it/s]
# {'epoch': 60, 'rec_loss': '0.4507'}
# Recommendation EP_test:60: 100% 88/88 [00:01<00:00, 59.66it/s]
# {'Epoch': 60, 'HIT@1': '0.2243', 'NDCG@1': '0.2243', 'HIT@5': '0.4311', 'NDCG@5': '0.3337', 'HIT@10': '0.5311', 'NDCG@10': '0.3659', 'MRR': '0.3307'}
# EarlyStopping counter: 5 out of 10
# Recommendation EP_train:61: 100% 587/587 [00:12<00:00, 48.13it/s]
# {'epoch': 61, 'rec_loss': '0.4506'}
# Recommendation EP_test:61: 100% 88/88 [00:01<00:00, 67.36it/s]
# {'Epoch': 61, 'HIT@1': '0.2239', 'NDCG@1': '0.2239', 'HIT@5': '0.4327', 'NDCG@5': '0.3345', 'HIT@10': '0.5310', 'NDCG@10': '0.3663', 'MRR': '0.3311'}
# EarlyStopping counter: 6 out of 10
# Recommendation EP_train:62: 100% 587/587 [00:12<00:00, 48.13it/s]
# {'epoch': 62, 'rec_loss': '0.4489'}
# Recommendation EP_test:62: 100% 88/88 [00:01<00:00, 59.88it/s]
# {'Epoch': 62, 'HIT@1': '0.2241', 'NDCG@1': '0.2241', 'HIT@5': '0.4334', 'NDCG@5': '0.3344', 'HIT@10': '0.5297', 'NDCG@10': '0.3655', 'MRR': '0.3306'}
# EarlyStopping counter: 7 out of 10
# Recommendation EP_train:63: 100% 587/587 [00:12<00:00, 48.28it/s]
# {'epoch': 63, 'rec_loss': '0.4461'}
# Recommendation EP_test:63: 100% 88/88 [00:01<00:00, 68.32it/s]
# {'Epoch': 63, 'HIT@1': '0.2225', 'NDCG@1': '0.2225', 'HIT@5': '0.4345', 'NDCG@5': '0.3345', 'HIT@10': '0.5321', 'NDCG@10': '0.3659', 'MRR': '0.3303'}
# EarlyStopping counter: 8 out of 10
# Recommendation EP_train:64: 100% 587/587 [00:12<00:00, 48.27it/s]
# {'epoch': 64, 'rec_loss': '0.4472'}
# Recommendation EP_test:64: 100% 88/88 [00:01<00:00, 59.70it/s]
# {'Epoch': 64, 'HIT@1': '0.2254', 'NDCG@1': '0.2254', 'HIT@5': '0.4359', 'NDCG@5': '0.3364', 'HIT@10': '0.5324', 'NDCG@10': '0.3676', 'MRR': '0.3324'}
# Validation score increased.  Saving model ...
# Recommendation EP_train:65: 100% 587/587 [00:12<00:00, 47.59it/s]
# {'epoch': 65, 'rec_loss': '0.4446'}
# Recommendation EP_test:65: 100% 88/88 [00:01<00:00, 51.26it/s]
# {'Epoch': 65, 'HIT@1': '0.2239', 'NDCG@1': '0.2239', 'HIT@5': '0.4333', 'NDCG@5': '0.3343', 'HIT@10': '0.5341', 'NDCG@10': '0.3667', 'MRR': '0.3307'}
# EarlyStopping counter: 1 out of 10
# Recommendation EP_train:66: 100% 587/587 [00:12<00:00, 47.85it/s]
# {'epoch': 66, 'rec_loss': '0.4480'}
# Recommendation EP_test:66: 100% 88/88 [00:01<00:00, 59.96it/s]
# {'Epoch': 66, 'HIT@1': '0.2256', 'NDCG@1': '0.2256', 'HIT@5': '0.4364', 'NDCG@5': '0.3368', 'HIT@10': '0.5336', 'NDCG@10': '0.3681', 'MRR': '0.3326'}
# Validation score increased.  Saving model ...
# Recommendation EP_train:67: 100% 587/587 [00:12<00:00, 48.18it/s]
# {'epoch': 67, 'rec_loss': '0.4445'}
# Recommendation EP_test:67: 100% 88/88 [00:01<00:00, 66.66it/s]
# {'Epoch': 67, 'HIT@1': '0.2281', 'NDCG@1': '0.2281', 'HIT@5': '0.4356', 'NDCG@5': '0.3374', 'HIT@10': '0.5317', 'NDCG@10': '0.3685', 'MRR': '0.3339'}
# Validation score increased.  Saving model ...
# Recommendation EP_train:68: 100% 587/587 [00:12<00:00, 47.73it/s]
# {'epoch': 68, 'rec_loss': '0.4450'}
# Recommendation EP_test:68: 100% 88/88 [00:01<00:00, 59.77it/s]
# {'Epoch': 68, 'HIT@1': '0.2281', 'NDCG@1': '0.2281', 'HIT@5': '0.4356', 'NDCG@5': '0.3378', 'HIT@10': '0.5312', 'NDCG@10': '0.3686', 'MRR': '0.3343'}
# Validation score increased.  Saving model ...
# Recommendation EP_train:69: 100% 587/587 [00:12<00:00, 47.52it/s]
# {'epoch': 69, 'rec_loss': '0.4407'}
# Recommendation EP_test:69: 100% 88/88 [00:01<00:00, 65.69it/s]
# {'Epoch': 69, 'HIT@1': '0.2251', 'NDCG@1': '0.2251', 'HIT@5': '0.4331', 'NDCG@5': '0.3349', 'HIT@10': '0.5313', 'NDCG@10': '0.3666', 'MRR': '0.3316'}
# EarlyStopping counter: 1 out of 10
# Recommendation EP_train:70: 100% 587/587 [00:12<00:00, 47.67it/s]
# {'epoch': 70, 'rec_loss': '0.4403'}
# Recommendation EP_test:70: 100% 88/88 [00:01<00:00, 45.56it/s]
# {'Epoch': 70, 'HIT@1': '0.2245', 'NDCG@1': '0.2245', 'HIT@5': '0.4335', 'NDCG@5': '0.3352', 'HIT@10': '0.5312', 'NDCG@10': '0.3667', 'MRR': '0.3316'}
# EarlyStopping counter: 2 out of 10
# Recommendation EP_train:71: 100% 587/587 [00:12<00:00, 47.75it/s]
# {'epoch': 71, 'rec_loss': '0.4364'}
# Recommendation EP_test:71: 100% 88/88 [00:01<00:00, 66.44it/s]
# {'Epoch': 71, 'HIT@1': '0.2256', 'NDCG@1': '0.2256', 'HIT@5': '0.4358', 'NDCG@5': '0.3367', 'HIT@10': '0.5330', 'NDCG@10': '0.3681', 'MRR': '0.3328'}
# EarlyStopping counter: 3 out of 10
# Recommendation EP_train:72: 100% 587/587 [00:12<00:00, 48.05it/s]
# {'epoch': 72, 'rec_loss': '0.4379'}
# Recommendation EP_test:72: 100% 88/88 [00:01<00:00, 58.53it/s]
# {'Epoch': 72, 'HIT@1': '0.2261', 'NDCG@1': '0.2261', 'HIT@5': '0.4363', 'NDCG@5': '0.3370', 'HIT@10': '0.5342', 'NDCG@10': '0.3687', 'MRR': '0.3332'}
# EarlyStopping counter: 4 out of 10
# Recommendation EP_train:73: 100% 587/587 [00:12<00:00, 47.83it/s]
# {'epoch': 73, 'rec_loss': '0.4406'}
# Recommendation EP_test:73: 100% 88/88 [00:01<00:00, 66.07it/s]
# {'Epoch': 73, 'HIT@1': '0.2281', 'NDCG@1': '0.2281', 'HIT@5': '0.4374', 'NDCG@5': '0.3383', 'HIT@10': '0.5324', 'NDCG@10': '0.3689', 'MRR': '0.3342'}
# EarlyStopping counter: 5 out of 10
# Recommendation EP_train:74: 100% 587/587 [00:12<00:00, 47.59it/s]
# {'epoch': 74, 'rec_loss': '0.4366'}
# Recommendation EP_test:74: 100% 88/88 [00:01<00:00, 59.70it/s]
# {'Epoch': 74, 'HIT@1': '0.2265', 'NDCG@1': '0.2265', 'HIT@5': '0.4376', 'NDCG@5': '0.3374', 'HIT@10': '0.5336', 'NDCG@10': '0.3684', 'MRR': '0.3330'}
# EarlyStopping counter: 6 out of 10
# Recommendation EP_train:75: 100% 587/587 [00:12<00:00, 47.74it/s]
# {'epoch': 75, 'rec_loss': '0.4374'}
# Recommendation EP_test:75: 100% 88/88 [00:01<00:00, 64.98it/s]
# {'Epoch': 75, 'HIT@1': '0.2271', 'NDCG@1': '0.2271', 'HIT@5': '0.4389', 'NDCG@5': '0.3390', 'HIT@10': '0.5359', 'NDCG@10': '0.3702', 'MRR': '0.3345'}
# Validation score increased.  Saving model ...
# Recommendation EP_train:76: 100% 587/587 [00:12<00:00, 48.22it/s]
# {'epoch': 76, 'rec_loss': '0.4378'}
# Recommendation EP_test:76: 100% 88/88 [00:01<00:00, 45.92it/s]
# {'Epoch': 76, 'HIT@1': '0.2240', 'NDCG@1': '0.2240', 'HIT@5': '0.4341', 'NDCG@5': '0.3351', 'HIT@10': '0.5329', 'NDCG@10': '0.3670', 'MRR': '0.3314'}
# EarlyStopping counter: 1 out of 10
# Recommendation EP_train:77: 100% 587/587 [00:12<00:00, 47.87it/s]
# {'epoch': 77, 'rec_loss': '0.4365'}
# Recommendation EP_test:77: 100% 88/88 [00:01<00:00, 67.88it/s]
# {'Epoch': 77, 'HIT@1': '0.2260', 'NDCG@1': '0.2260', 'HIT@5': '0.4361', 'NDCG@5': '0.3370', 'HIT@10': '0.5353', 'NDCG@10': '0.3690', 'MRR': '0.3333'}
# EarlyStopping counter: 2 out of 10
# Recommendation EP_train:78: 100% 587/587 [00:12<00:00, 47.79it/s]
# {'epoch': 78, 'rec_loss': '0.4358'}
# Recommendation EP_test:78: 100% 88/88 [00:01<00:00, 59.28it/s]
# {'Epoch': 78, 'HIT@1': '0.2277', 'NDCG@1': '0.2277', 'HIT@5': '0.4374', 'NDCG@5': '0.3383', 'HIT@10': '0.5366', 'NDCG@10': '0.3703', 'MRR': '0.3346'}
# Validation score increased.  Saving model ...
# Recommendation EP_train:79: 100% 587/587 [00:12<00:00, 47.54it/s]
# {'epoch': 79, 'rec_loss': '0.4320'}
# Recommendation EP_test:79: 100% 88/88 [00:01<00:00, 66.97it/s]
# {'Epoch': 79, 'HIT@1': '0.2262', 'NDCG@1': '0.2262', 'HIT@5': '0.4376', 'NDCG@5': '0.3371', 'HIT@10': '0.5349', 'NDCG@10': '0.3684', 'MRR': '0.3327'}
# EarlyStopping counter: 1 out of 10
# Recommendation EP_train:80: 100% 587/587 [00:12<00:00, 48.07it/s]
# {'epoch': 80, 'rec_loss': '0.4326'}
# Recommendation EP_test:80: 100% 88/88 [00:01<00:00, 62.48it/s]
# {'Epoch': 80, 'HIT@1': '0.2255', 'NDCG@1': '0.2255', 'HIT@5': '0.4347', 'NDCG@5': '0.3358', 'HIT@10': '0.5341', 'NDCG@10': '0.3678', 'MRR': '0.3322'}
# EarlyStopping counter: 2 out of 10
# Recommendation EP_train:81: 100% 587/587 [00:12<00:00, 47.91it/s]
# {'epoch': 81, 'rec_loss': '0.4315'}
# Recommendation EP_test:81: 100% 88/88 [00:01<00:00, 57.18it/s]
# {'Epoch': 81, 'HIT@1': '0.2253', 'NDCG@1': '0.2253', 'HIT@5': '0.4372', 'NDCG@5': '0.3372', 'HIT@10': '0.5336', 'NDCG@10': '0.3684', 'MRR': '0.3330'}
# EarlyStopping counter: 3 out of 10
# Recommendation EP_train:82: 100% 587/587 [00:12<00:00, 47.31it/s]
# {'epoch': 82, 'rec_loss': '0.4288'}
# Recommendation EP_test:82: 100% 88/88 [00:01<00:00, 53.03it/s]
# {'Epoch': 82, 'HIT@1': '0.2283', 'NDCG@1': '0.2283', 'HIT@5': '0.4381', 'NDCG@5': '0.3388', 'HIT@10': '0.5355', 'NDCG@10': '0.3701', 'MRR': '0.3346'}
# Validation score increased.  Saving model ...
# Recommendation EP_train:83: 100% 587/587 [00:12<00:00, 47.90it/s]
# {'epoch': 83, 'rec_loss': '0.4327'}
# Recommendation EP_test:83: 100% 88/88 [00:01<00:00, 66.02it/s]
# {'Epoch': 83, 'HIT@1': '0.2316', 'NDCG@1': '0.2316', 'HIT@5': '0.4403', 'NDCG@5': '0.3417', 'HIT@10': '0.5362', 'NDCG@10': '0.3726', 'MRR': '0.3377'}
# Validation score increased.  Saving model ...
# Recommendation EP_train:84: 100% 587/587 [00:11<00:00, 49.00it/s]
# {'epoch': 84, 'rec_loss': '0.4333'}
# Recommendation EP_test:84: 100% 88/88 [00:01<00:00, 62.97it/s]
# {'Epoch': 84, 'HIT@1': '0.2305', 'NDCG@1': '0.2305', 'HIT@5': '0.4402', 'NDCG@5': '0.3413', 'HIT@10': '0.5371', 'NDCG@10': '0.3725', 'MRR': '0.3372'}
# EarlyStopping counter: 1 out of 10
# Recommendation EP_train:85: 100% 587/587 [00:11<00:00, 48.94it/s]
# {'epoch': 85, 'rec_loss': '0.4304'}
# Recommendation EP_test:85: 100% 88/88 [00:01<00:00, 70.35it/s]
# {'Epoch': 85, 'HIT@1': '0.2314', 'NDCG@1': '0.2314', 'HIT@5': '0.4393', 'NDCG@5': '0.3409', 'HIT@10': '0.5369', 'NDCG@10': '0.3724', 'MRR': '0.3372'}
# EarlyStopping counter: 2 out of 10
# Recommendation EP_train:86: 100% 587/587 [00:12<00:00, 48.91it/s]
# {'epoch': 86, 'rec_loss': '0.4307'}
# Recommendation EP_test:86: 100% 88/88 [00:01<00:00, 62.67it/s]
# {'Epoch': 86, 'HIT@1': '0.2308', 'NDCG@1': '0.2308', 'HIT@5': '0.4387', 'NDCG@5': '0.3404', 'HIT@10': '0.5373', 'NDCG@10': '0.3722', 'MRR': '0.3368'}
# EarlyStopping counter: 3 out of 10
# Recommendation EP_train:87: 100% 587/587 [00:11<00:00, 48.93it/s]
# {'epoch': 87, 'rec_loss': '0.4270'}
# Recommendation EP_test:87: 100% 88/88 [00:01<00:00, 67.40it/s]
# {'Epoch': 87, 'HIT@1': '0.2291', 'NDCG@1': '0.2291', 'HIT@5': '0.4386', 'NDCG@5': '0.3396', 'HIT@10': '0.5355', 'NDCG@10': '0.3709', 'MRR': '0.3358'}
# EarlyStopping counter: 4 out of 10
# Recommendation EP_train:88: 100% 587/587 [00:12<00:00, 48.79it/s]
# {'epoch': 88, 'rec_loss': '0.4274'}
# Recommendation EP_test:88: 100% 88/88 [00:01<00:00, 48.57it/s]
# {'Epoch': 88, 'HIT@1': '0.2281', 'NDCG@1': '0.2281', 'HIT@5': '0.4393', 'NDCG@5': '0.3400', 'HIT@10': '0.5360', 'NDCG@10': '0.3711', 'MRR': '0.3358'}
# EarlyStopping counter: 5 out of 10
# Recommendation EP_train:89: 100% 587/587 [00:12<00:00, 48.88it/s]
# {'epoch': 89, 'rec_loss': '0.4281'}
# Recommendation EP_test:89: 100% 88/88 [00:01<00:00, 70.68it/s]
# {'Epoch': 89, 'HIT@1': '0.2277', 'NDCG@1': '0.2277', 'HIT@5': '0.4392', 'NDCG@5': '0.3391', 'HIT@10': '0.5345', 'NDCG@10': '0.3699', 'MRR': '0.3348'}
# EarlyStopping counter: 6 out of 10
# Recommendation EP_train:90: 100% 587/587 [00:11<00:00, 48.94it/s]
# {'epoch': 90, 'rec_loss': '0.4281'}
# Recommendation EP_test:90: 100% 88/88 [00:01<00:00, 62.96it/s]
# {'Epoch': 90, 'HIT@1': '0.2311', 'NDCG@1': '0.2311', 'HIT@5': '0.4380', 'NDCG@5': '0.3406', 'HIT@10': '0.5387', 'NDCG@10': '0.3731', 'MRR': '0.3375'}
# EarlyStopping counter: 7 out of 10
# Recommendation EP_train:91: 100% 587/587 [00:12<00:00, 48.83it/s]
# {'epoch': 91, 'rec_loss': '0.4279'}
# Recommendation EP_test:91: 100% 88/88 [00:01<00:00, 69.34it/s]
# {'Epoch': 91, 'HIT@1': '0.2297', 'NDCG@1': '0.2297', 'HIT@5': '0.4380', 'NDCG@5': '0.3398', 'HIT@10': '0.5371', 'NDCG@10': '0.3718', 'MRR': '0.3364'}
# EarlyStopping counter: 8 out of 10
# Recommendation EP_train:92: 100% 587/587 [00:12<00:00, 48.87it/s]
# {'epoch': 92, 'rec_loss': '0.4256'}
# Recommendation EP_test:92: 100% 88/88 [00:01<00:00, 62.44it/s]
# {'Epoch': 92, 'HIT@1': '0.2310', 'NDCG@1': '0.2310', 'HIT@5': '0.4388', 'NDCG@5': '0.3407', 'HIT@10': '0.5387', 'NDCG@10': '0.3730', 'MRR': '0.3374'}
# EarlyStopping counter: 9 out of 10
# Recommendation EP_train:93: 100% 587/587 [00:11<00:00, 49.07it/s]
# {'epoch': 93, 'rec_loss': '0.4277'}
# Recommendation EP_test:93: 100% 88/88 [00:01<00:00, 69.13it/s]
# {'Epoch': 93, 'HIT@1': '0.2290', 'NDCG@1': '0.2290', 'HIT@5': '0.4416', 'NDCG@5': '0.3412', 'HIT@10': '0.5362', 'NDCG@10': '0.3718', 'MRR': '0.3366'}
# EarlyStopping counter: 10 out of 10
# Early stopping
# ---------------Sample 99 results---------------
# /content/FMLP-Rec/main.py:107: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   trainer.model.load_state_dict(torch.load(args.checkpoint_path))
# Recommendation EP_test:0: 100% 88/88 [00:01<00:00, 63.73it/s]
# {'Epoch': 0, 'HIT@1': '0.1987', 'NDCG@1': '0.1987', 'HIT@5': '0.4019', 'NDCG@5': '0.3055', 'HIT@10': '0.4956', 'NDCG@10': '0.3358', 'MRR': '0.3031'}
# FMLPRec-Beauty-Feb-20-2025_07-59-31
# {'Epoch': 0, 'HIT@1': '0.1987', 'NDCG@1': '0.1987', 'HIT@5': '0.4019', 'NDCG@5': '0.3055', 'HIT@10': '0.4956', 'NDCG@10': '0.3358', 'MRR': '0.3031'}

# %% [markdown]
# Paper Evaluation results (Amazon Beauty dataset):
#
# * HR@1 (HIT@1): 0.2011
# * HR@5: 0.4025
# * NDCG@5: 0.3070
# * HR@10: 0.4998
# * NDCG@10: 0.3385
# * MRR: 0.3051

# %% [markdown]
# Reproduction Evaluation results:
# * HR@1: 0.1987
# * HR@5: 0.4019
# * NDCG@5: 0.3055
# * HR@10: 0.4956
# * NDCG@10: 0.3358
# * MRR: 0.3031

# %% [markdown]
# ### Run FMLP-Rec on MovieLens Dataset

# %% [markdown]
# #### Preprocess ML-1M Dataset

# %%
# !git clone https://github.com/RUCAIBox/FMLP-Rec.git
# Out:
# Cloning into 'FMLP-Rec'...
# remote: Enumerating objects: 20, done.
# remote: Counting objects: 100% (20/20), done.
# remote: Compressing objects: 100% (20/20), done.
# remote: Total 20 (delta 0), reused 20 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (20/20), 8.41 MiB | 15.06 MiB/s, done.

# %%
import pandas as pd
import numpy as np
import zipfile
import os
from collections import Counter
import csv
import shutil

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data_file = '/content/drive/Shareddrives/RecSys/ml-1m.zip'
extract_path = 'ml-1m'
ratings_file = 'ml-1m/ratings.dat'

# %%
processed_file = "ML-1M.txt"
sample_file = "ML-1M_sample.txt"
destination_folder = "FMLP-Rec/data/"

# %%
def convert_zip_to_df(zip_path, extract_path, ratings_file):
    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        zip_ref.extractall(extract_path)

    ml1m_path = os.path.join(extract_path, ratings_file)
    df = pd.read_csv(ml1m_path, sep="::", engine="python", names=["user_id", "item_id", "rating", "timestamp"])
    return df

# %%
def filter_k_core(df, k=5):
    while True:
        user_counts = df["user_id"].value_counts()
        item_counts = df["item_id"].value_counts()

        df = df[df["user_id"].isin(user_counts[user_counts >= k].index)]
        df = df[df["item_id"].isin(item_counts[item_counts >= k].index)]

        new_user_counts = df["user_id"].value_counts()
        new_item_counts = df["item_id"].value_counts()

        if len(new_user_counts) == len(user_counts) and len(new_item_counts) == len(item_counts):
            break
    return df

# %%
def run_preprocess(data_file, extract_path, ratings_file, min_rating=0):

    data = convert_zip_to_df(data_file, extract_path, ratings_file)

    # Keep only interactions where rating > min_rating
    data = data[data["rating"] > min_rating]

    # apply k-core filtering (ensuring each user and item has at least k interactions)
    # data = filter_k_core(data, k=5)

    user_map = {old: new+1 for new, old in enumerate(data["user_id"].unique())}
    item_map = {old: new+1 for new, old in enumerate(data["item_id"].unique())}

    data["user_id"] = data["user_id"].map(user_map)
    data["item_id"] = data["item_id"].map(item_map)

    # group by user_id, sort by timestamp, and aggregate item interactions
    data = data.sort_values(by=["user_id", "timestamp"])
    grouped = data.groupby("user_id")["item_id"].apply(list).to_dict()

    grouped_data = data.groupby("user_id")["item_id"].apply(lambda x: " ".join(map(str, x))).reset_index()
    grouped_data["formatted"] = grouped_data["user_id"].astype(str) + " " + grouped_data["item_id"]
    grouped_data["formatted"].to_csv(f"{processed_file}", index=False, header=False)

    print(f"Processing complete. Saved as {processed_file}")

    # 99 negative samples per user required
    all_items = set(data["item_id"].unique())

    with open(sample_file, "w") as f:
        for user_id, pos_items in grouped.items():
            positive_items = set(pos_items) if isinstance(pos_items, (set, list, pd.Series)) else {pos_items}
            negative_samples = list(all_items - positive_items)
            sampled_negatives = np.random.choice(negative_samples, 99, replace=False) if len(negative_samples) >= 99 else negative_samples
            f.write(f"{user_id} " + " ".join(map(str, sampled_negatives)) + "\n")

    print(f"Sample file '{sample_file}' created successfully.")

# %%
run_preprocess(data_file, extract_path, ratings_file)
# Out:
# Processing complete. Saved as ML-1M.txt
# Sample file 'ML-1M_sample.txt' created successfully.

# %%
os.makedirs(destination_folder, exist_ok=True)
shutil.move(processed_file, os.path.join(destination_folder, processed_file))
shutil.move(sample_file, os.path.join(destination_folder, sample_file))

print(f"Files moved to {destination_folder}")
# Out:
# Files moved to FMLP-Rec/data/

# %% [markdown]
# #### Run FMLP on ML-1M Dataset

# %%
# !sed -i "s/^sequential_data_list = \['Beauty','Sports_and_Outdoors','Toys_and_Games','Yelp'\]/sequential_data_list = \['Beauty','Sports_and_Outdoors','Toys_and_Games','Yelp','ML-1M'\]/" /content/FMLP-Rec/utils.py

# %%
# !cd /content/FMLP-Rec/ && python main.py --data_name='ML-1M'
# Out:
# Namespace(data_dir='./data/', output_dir='output/', data_name='ML-1M', do_eval=False, load_model=None, model_name='FMLPRec', hidden_size=64, num_hidden_layers=2, num_attention_heads=2, hidden_act='gelu', attention_probs_dropout_prob=0.5, hidden_dropout_prob=0.5, initializer_range=0.02, max_seq_length=50, no_filters=False, lr=0.001, batch_size=256, epochs=200, no_cuda=False, log_freq=1, full_sort=False, patience=10, seed=42, weight_decay=0.0, adam_beta1=0.9, adam_beta2=0.999, gpu_id='0', variance=5, cuda_condition=True, data_file='./data/ML-1M.txt', sample_file='./data/ML-1M_sample.txt', item_size=3707, log_file='output/FMLPRec-ML-1M-Feb-21-2025_12-56-17.txt')
# Total Parameters: 313920
# Recommendation EP_train:0: 100% 1047/1047 [00:24<00:00, 42.39it/s]
# {'epoch': 0, 'rec_loss': '1.0011'}
# Recommendation EP_test:0: 100% 24/24 [00:00<00:00, 56.40it/s]
# {'Epoch': 0, 'HIT@1': '0.1916', 'NDCG@1': '0.1916', 'HIT@5': '0.4793', 'NDCG@5': '0.3406', 'HIT@10': '0.6445', 'NDCG@10': '0.3941', 'MRR': '0.3341'}
# Validation score increased.  Saving model ...
# Recommendation EP_train:1: 100% 1047/1047 [00:24<00:00, 42.82it/s]
# {'epoch': 1, 'rec_loss': '0.7848'}
# Recommendation EP_test:1: 100% 24/24 [00:00<00:00, 62.36it/s]
# {'Epoch': 1, 'HIT@1': '0.2826', 'NDCG@1': '0.2826', 'HIT@5': '0.6132', 'NDCG@5': '0.4552', 'HIT@10': '0.7523', 'NDCG@10': '0.5004', 'MRR': '0.4335'}
# Validation score increased.  Saving model ...
# Recommendation EP_train:2: 100% 1047/1047 [00:22<00:00, 46.33it/s]
# {'epoch': 2, 'rec_loss': '0.6985'}
# Recommendation EP_test:2: 100% 24/24 [00:00<00:00, 64.21it/s]
# {'Epoch': 2, 'HIT@1': '0.3015', 'NDCG@1': '0.3015', 'HIT@5': '0.6459', 'NDCG@5': '0.4831', 'HIT@10': '0.7796', 'NDCG@10': '0.5266', 'MRR': '0.4577'}
# Validation score increased.  Saving model ...
# Recommendation EP_train:3: 100% 1047/1047 [00:22<00:00, 46.77it/s]
# {'epoch': 3, 'rec_loss': '0.6611'}
# Recommendation EP_test:3: 100% 24/24 [00:00<00:00, 40.52it/s]
# {'Epoch': 3, 'HIT@1': '0.3258', 'NDCG@1': '0.3258', 'HIT@5': '0.6697', 'NDCG@5': '0.5082', 'HIT@10': '0.7940', 'NDCG@10': '0.5484', 'MRR': '0.4809'}
# Validation score increased.  Saving model ...
# Recommendation EP_train:4: 100% 1047/1047 [00:21<00:00, 47.76it/s]
# {'epoch': 4, 'rec_loss': '0.6323'}
# Recommendation EP_test:4: 100% 24/24 [00:00<00:00, 60.01it/s]
# {'Epoch': 4, 'HIT@1': '0.3326', 'NDCG@1': '0.3326', 'HIT@5': '0.6846', 'NDCG@5': '0.5206', 'HIT@10': '0.8050', 'NDCG@10': '0.5597', 'MRR': '0.4914'}
# Validation score increased.  Saving model ...
# Recommendation EP_train:5: 100% 1047/1047 [00:22<00:00, 46.72it/s]
# {'epoch': 5, 'rec_loss': '0.6124'}
# Recommendation EP_test:5: 100% 24/24 [00:00<00:00, 61.28it/s]
# {'Epoch': 5, 'HIT@1': '0.3422', 'NDCG@1': '0.3422', 'HIT@5': '0.6929', 'NDCG@5': '0.5291', 'HIT@10': '0.8108', 'NDCG@10': '0.5675', 'MRR': '0.4995'}
# Validation score increased.  Saving model ...
# Recommendation EP_train:6: 100% 1047/1047 [00:22<00:00, 46.34it/s]
# {'epoch': 6, 'rec_loss': '0.5973'}
# Recommendation EP_test:6: 100% 24/24 [00:00<00:00, 60.91it/s]
# {'Epoch': 6, 'HIT@1': '0.3492', 'NDCG@1': '0.3492', 'HIT@5': '0.6980', 'NDCG@5': '0.5351', 'HIT@10': '0.8121', 'NDCG@10': '0.5723', 'MRR': '0.5054'}
# Validation score increased.  Saving model ...
# Recommendation EP_train:7: 100% 1047/1047 [00:21<00:00, 48.10it/s]
# {'epoch': 7, 'rec_loss': '0.5881'}
# Recommendation EP_test:7: 100% 24/24 [00:00<00:00, 43.65it/s]
# {'Epoch': 7, 'HIT@1': '0.3517', 'NDCG@1': '0.3517', 'HIT@5': '0.6987', 'NDCG@5': '0.5370', 'HIT@10': '0.8127', 'NDCG@10': '0.5743', 'MRR': '0.5076'}
# Validation score increased.  Saving model ...
# Recommendation EP_train:8: 100% 1047/1047 [00:22<00:00, 47.03it/s]
# {'epoch': 8, 'rec_loss': '0.5810'}
# Recommendation EP_test:8: 100% 24/24 [00:00<00:00, 62.35it/s]
# {'Epoch': 8, 'HIT@1': '0.3497', 'NDCG@1': '0.3497', 'HIT@5': '0.7003', 'NDCG@5': '0.5374', 'HIT@10': '0.8119', 'NDCG@10': '0.5737', 'MRR': '0.5073'}
# EarlyStopping counter: 1 out of 10
# Recommendation EP_train:9: 100% 1047/1047 [00:22<00:00, 47.10it/s]
# {'epoch': 9, 'rec_loss': '0.5728'}
# Recommendation EP_test:9: 100% 24/24 [00:00<00:00, 41.67it/s]
# {'Epoch': 9, 'HIT@1': '0.3566', 'NDCG@1': '0.3566', 'HIT@5': '0.7031', 'NDCG@5': '0.5416', 'HIT@10': '0.8151', 'NDCG@10': '0.5782', 'MRR': '0.5120'}
# Validation score increased.  Saving model ...
# Recommendation EP_train:10: 100% 1047/1047 [00:22<00:00, 46.82it/s]
# {'epoch': 10, 'rec_loss': '0.5658'}
# Recommendation EP_test:10: 100% 24/24 [00:00<00:00, 54.52it/s]
# {'Epoch': 10, 'HIT@1': '0.3474', 'NDCG@1': '0.3474', 'HIT@5': '0.7053', 'NDCG@5': '0.5389', 'HIT@10': '0.8167', 'NDCG@10': '0.5752', 'MRR': '0.5073'}
# EarlyStopping counter: 1 out of 10
# Recommendation EP_train:11: 100% 1047/1047 [00:22<00:00, 47.39it/s]
# {'epoch': 11, 'rec_loss': '0.5604'}
# Recommendation EP_test:11: 100% 24/24 [00:00<00:00, 62.37it/s]
# {'Epoch': 11, 'HIT@1': '0.3578', 'NDCG@1': '0.3578', 'HIT@5': '0.7026', 'NDCG@5': '0.5424', 'HIT@10': '0.8164', 'NDCG@10': '0.5794', 'MRR': '0.5130'}
# Validation score increased.  Saving model ...
# Recommendation EP_train:12: 100% 1047/1047 [00:22<00:00, 46.72it/s]
# {'epoch': 12, 'rec_loss': '0.5556'}
# Recommendation EP_test:12: 100% 24/24 [00:00<00:00, 63.50it/s]
# {'Epoch': 12, 'HIT@1': '0.3533', 'NDCG@1': '0.3533', 'HIT@5': '0.7111', 'NDCG@5': '0.5442', 'HIT@10': '0.8190', 'NDCG@10': '0.5795', 'MRR': '0.5121'}
# EarlyStopping counter: 1 out of 10
# Recommendation EP_train:13: 100% 1047/1047 [00:24<00:00, 42.63it/s]
# {'epoch': 13, 'rec_loss': '0.5503'}
# Recommendation EP_test:13: 100% 24/24 [00:00<00:00, 61.74it/s]
# {'Epoch': 13, 'HIT@1': '0.3525', 'NDCG@1': '0.3525', 'HIT@5': '0.7081', 'NDCG@5': '0.5440', 'HIT@10': '0.8142', 'NDCG@10': '0.5786', 'MRR': '0.5124'}
# EarlyStopping counter: 2 out of 10
# Recommendation EP_train:14: 100% 1047/1047 [00:23<00:00, 44.73it/s]
# {'epoch': 14, 'rec_loss': '0.5500'}
# Recommendation EP_test:14: 100% 24/24 [00:00<00:00, 62.55it/s]
# {'Epoch': 14, 'HIT@1': '0.3558', 'NDCG@1': '0.3558', 'HIT@5': '0.7114', 'NDCG@5': '0.5465', 'HIT@10': '0.8199', 'NDCG@10': '0.5819', 'MRR': '0.5148'}
# Validation score increased.  Saving model ...
# Recommendation EP_train:15: 100% 1047/1047 [00:21<00:00, 48.27it/s]
# {'epoch': 15, 'rec_loss': '0.5473'}
# Recommendation EP_test:15: 100% 24/24 [00:00<00:00, 59.15it/s]
# {'Epoch': 15, 'HIT@1': '0.3692', 'NDCG@1': '0.3692', 'HIT@5': '0.7149', 'NDCG@5': '0.5546', 'HIT@10': '0.8224', 'NDCG@10': '0.5894', 'MRR': '0.5240'}
# Validation score increased.  Saving model ...
# Recommendation EP_train:16: 100% 1047/1047 [00:22<00:00, 46.42it/s]
# {'epoch': 16, 'rec_loss': '0.5416'}
# Recommendation EP_test:16: 100% 24/24 [00:00<00:00, 62.34it/s]
# {'Epoch': 16, 'HIT@1': '0.3644', 'NDCG@1': '0.3644', 'HIT@5': '0.7114', 'NDCG@5': '0.5503', 'HIT@10': '0.8149', 'NDCG@10': '0.5840', 'MRR': '0.5196'}
# EarlyStopping counter: 1 out of 10
# Recommendation EP_train:17: 100% 1047/1047 [00:22<00:00, 46.65it/s]
# {'epoch': 17, 'rec_loss': '0.5395'}
# Recommendation EP_test:17: 100% 24/24 [00:00<00:00, 63.79it/s]
# {'Epoch': 17, 'HIT@1': '0.3694', 'NDCG@1': '0.3694', 'HIT@5': '0.7243', 'NDCG@5': '0.5599', 'HIT@10': '0.8222', 'NDCG@10': '0.5919', 'MRR': '0.5269'}
# Validation score increased.  Saving model ...
# Recommendation EP_train:18: 100% 1047/1047 [00:21<00:00, 47.64it/s]
# {'epoch': 18, 'rec_loss': '0.5372'}
# Recommendation EP_test:18: 100% 24/24 [00:00<00:00, 39.61it/s]
# {'Epoch': 18, 'HIT@1': '0.3596', 'NDCG@1': '0.3596', 'HIT@5': '0.7195', 'NDCG@5': '0.5529', 'HIT@10': '0.8199', 'NDCG@10': '0.5856', 'MRR': '0.5195'}
# EarlyStopping counter: 1 out of 10
# Recommendation EP_train:19: 100% 1047/1047 [00:21<00:00, 47.72it/s]
# {'epoch': 19, 'rec_loss': '0.5358'}
# Recommendation EP_test:19: 100% 24/24 [00:00<00:00, 62.38it/s]
# {'Epoch': 19, 'HIT@1': '0.3629', 'NDCG@1': '0.3629', 'HIT@5': '0.7113', 'NDCG@5': '0.5514', 'HIT@10': '0.8197', 'NDCG@10': '0.5868', 'MRR': '0.5213'}
# EarlyStopping counter: 2 out of 10
# Recommendation EP_train:20: 100% 1047/1047 [00:22<00:00, 47.21it/s]
# {'epoch': 20, 'rec_loss': '0.5305'}
# Recommendation EP_test:20: 100% 24/24 [00:00<00:00, 62.52it/s]
# {'Epoch': 20, 'HIT@1': '0.3641', 'NDCG@1': '0.3641', 'HIT@5': '0.7167', 'NDCG@5': '0.5531', 'HIT@10': '0.8217', 'NDCG@10': '0.5873', 'MRR': '0.5213'}
# EarlyStopping counter: 3 out of 10
# Recommendation EP_train:21: 100% 1047/1047 [00:22<00:00, 46.94it/s]
# {'epoch': 21, 'rec_loss': '0.5294'}
# Recommendation EP_test:21: 100% 24/24 [00:00<00:00, 63.13it/s]
# {'Epoch': 21, 'HIT@1': '0.3738', 'NDCG@1': '0.3738', 'HIT@5': '0.7195', 'NDCG@5': '0.5592', 'HIT@10': '0.8237', 'NDCG@10': '0.5931', 'MRR': '0.5282'}
# Validation score increased.  Saving model ...
# Recommendation EP_train:22: 100% 1047/1047 [00:21<00:00, 48.18it/s]
# {'epoch': 22, 'rec_loss': '0.5270'}
# Recommendation EP_test:22: 100% 24/24 [00:00<00:00, 44.68it/s]
# {'Epoch': 22, 'HIT@1': '0.3659', 'NDCG@1': '0.3659', 'HIT@5': '0.7245', 'NDCG@5': '0.5581', 'HIT@10': '0.8233', 'NDCG@10': '0.5903', 'MRR': '0.5244'}
# EarlyStopping counter: 1 out of 10
# Recommendation EP_train:23: 100% 1047/1047 [00:21<00:00, 47.60it/s]
# {'epoch': 23, 'rec_loss': '0.5259'}
# Recommendation EP_test:23: 100% 24/24 [00:00<00:00, 63.48it/s]
# {'Epoch': 23, 'HIT@1': '0.3661', 'NDCG@1': '0.3661', 'HIT@5': '0.7161', 'NDCG@5': '0.5531', 'HIT@10': '0.8192', 'NDCG@10': '0.5868', 'MRR': '0.5215'}
# EarlyStopping counter: 2 out of 10
# Recommendation EP_train:24: 100% 1047/1047 [00:22<00:00, 47.00it/s]
# {'epoch': 24, 'rec_loss': '0.5242'}
# Recommendation EP_test:24: 100% 24/24 [00:00<00:00, 63.26it/s]
# {'Epoch': 24, 'HIT@1': '0.3772', 'NDCG@1': '0.3772', 'HIT@5': '0.7276', 'NDCG@5': '0.5640', 'HIT@10': '0.8247', 'NDCG@10': '0.5956', 'MRR': '0.5310'}
# Validation score increased.  Saving model ...
# Recommendation EP_train:25: 100% 1047/1047 [00:22<00:00, 47.58it/s]
# {'epoch': 25, 'rec_loss': '0.5235'}
# Recommendation EP_test:25: 100% 24/24 [00:00<00:00, 42.49it/s]
# {'Epoch': 25, 'HIT@1': '0.3672', 'NDCG@1': '0.3672', 'HIT@5': '0.7172', 'NDCG@5': '0.5551', 'HIT@10': '0.8225', 'NDCG@10': '0.5894', 'MRR': '0.5236'}
# EarlyStopping counter: 1 out of 10
# Recommendation EP_train:26: 100% 1047/1047 [00:21<00:00, 48.23it/s]
# {'epoch': 26, 'rec_loss': '0.5219'}
# Recommendation EP_test:26: 100% 24/24 [00:00<00:00, 64.06it/s]
# {'Epoch': 26, 'HIT@1': '0.3790', 'NDCG@1': '0.3790', 'HIT@5': '0.7258', 'NDCG@5': '0.5641', 'HIT@10': '0.8242', 'NDCG@10': '0.5960', 'MRR': '0.5317'}
# Validation score increased.  Saving model ...
# Recommendation EP_train:27: 100% 1047/1047 [00:22<00:00, 46.90it/s]
# {'epoch': 27, 'rec_loss': '0.5209'}
# Recommendation EP_test:27: 100% 24/24 [00:00<00:00, 63.65it/s]
# {'Epoch': 27, 'HIT@1': '0.3737', 'NDCG@1': '0.3737', 'HIT@5': '0.7217', 'NDCG@5': '0.5610', 'HIT@10': '0.8204', 'NDCG@10': '0.5931', 'MRR': '0.5293'}
# EarlyStopping counter: 1 out of 10
# Recommendation EP_train:28: 100% 1047/1047 [00:22<00:00, 47.00it/s]
# {'epoch': 28, 'rec_loss': '0.5153'}
# Recommendation EP_test:28: 100% 24/24 [00:00<00:00, 63.30it/s]
# {'Epoch': 28, 'HIT@1': '0.3745', 'NDCG@1': '0.3745', 'HIT@5': '0.7257', 'NDCG@5': '0.5633', 'HIT@10': '0.8258', 'NDCG@10': '0.5959', 'MRR': '0.5308'}
# EarlyStopping counter: 2 out of 10
# Recommendation EP_train:29: 100% 1047/1047 [00:21<00:00, 48.56it/s]
# {'epoch': 29, 'rec_loss': '0.5162'}
# Recommendation EP_test:29: 100% 24/24 [00:00<00:00, 43.25it/s]
# {'Epoch': 29, 'HIT@1': '0.3793', 'NDCG@1': '0.3793', 'HIT@5': '0.7285', 'NDCG@5': '0.5677', 'HIT@10': '0.8278', 'NDCG@10': '0.6000', 'MRR': '0.5356'}
# Validation score increased.  Saving model ...
# Recommendation EP_train:30: 100% 1047/1047 [00:22<00:00, 47.59it/s]
# {'epoch': 30, 'rec_loss': '0.5119'}
# Recommendation EP_test:30: 100% 24/24 [00:00<00:00, 63.01it/s]
# {'Epoch': 30, 'HIT@1': '0.3717', 'NDCG@1': '0.3717', 'HIT@5': '0.7217', 'NDCG@5': '0.5596', 'HIT@10': '0.8230', 'NDCG@10': '0.5924', 'MRR': '0.5275'}
# EarlyStopping counter: 1 out of 10
# Recommendation EP_train:31: 100% 1047/1047 [00:21<00:00, 47.65it/s]
# {'epoch': 31, 'rec_loss': '0.5142'}
# Recommendation EP_test:31: 100% 24/24 [00:00<00:00, 41.81it/s]
# {'Epoch': 31, 'HIT@1': '0.3801', 'NDCG@1': '0.3801', 'HIT@5': '0.7227', 'NDCG@5': '0.5637', 'HIT@10': '0.8240', 'NDCG@10': '0.5967', 'MRR': '0.5329'}
# EarlyStopping counter: 2 out of 10
# Recommendation EP_train:32: 100% 1047/1047 [00:22<00:00, 47.51it/s]
# {'epoch': 32, 'rec_loss': '0.5133'}
# Recommendation EP_test:32: 100% 24/24 [00:00<00:00, 64.12it/s]
# {'Epoch': 32, 'HIT@1': '0.3730', 'NDCG@1': '0.3730', 'HIT@5': '0.7220', 'NDCG@5': '0.5607', 'HIT@10': '0.8238', 'NDCG@10': '0.5939', 'MRR': '0.5292'}
# EarlyStopping counter: 3 out of 10
# Recommendation EP_train:33: 100% 1047/1047 [00:21<00:00, 48.24it/s]
# {'epoch': 33, 'rec_loss': '0.5103'}
# Recommendation EP_test:33: 100% 24/24 [00:00<00:00, 47.96it/s]
# {'Epoch': 33, 'HIT@1': '0.3747', 'NDCG@1': '0.3747', 'HIT@5': '0.7263', 'NDCG@5': '0.5635', 'HIT@10': '0.8233', 'NDCG@10': '0.5950', 'MRR': '0.5307'}
# EarlyStopping counter: 4 out of 10
# Recommendation EP_train:34: 100% 1047/1047 [00:21<00:00, 47.68it/s]
# {'epoch': 34, 'rec_loss': '0.5102'}
# Recommendation EP_test:34: 100% 24/24 [00:00<00:00, 62.83it/s]
# {'Epoch': 34, 'HIT@1': '0.3757', 'NDCG@1': '0.3757', 'HIT@5': '0.7215', 'NDCG@5': '0.5620', 'HIT@10': '0.8243', 'NDCG@10': '0.5954', 'MRR': '0.5310'}
# EarlyStopping counter: 5 out of 10
# Recommendation EP_train:35: 100% 1047/1047 [00:22<00:00, 47.15it/s]
# {'epoch': 35, 'rec_loss': '0.5077'}
# Recommendation EP_test:35: 100% 24/24 [00:00<00:00, 61.92it/s]
# {'Epoch': 35, 'HIT@1': '0.3811', 'NDCG@1': '0.3811', 'HIT@5': '0.7243', 'NDCG@5': '0.5648', 'HIT@10': '0.8280', 'NDCG@10': '0.5985', 'MRR': '0.5338'}
# EarlyStopping counter: 6 out of 10
# Recommendation EP_train:36: 100% 1047/1047 [00:22<00:00, 47.07it/s]
# {'epoch': 36, 'rec_loss': '0.5051'}
# Recommendation EP_test:36: 100% 24/24 [00:00<00:00, 57.04it/s]
# {'Epoch': 36, 'HIT@1': '0.3808', 'NDCG@1': '0.3808', 'HIT@5': '0.7252', 'NDCG@5': '0.5654', 'HIT@10': '0.8276', 'NDCG@10': '0.5988', 'MRR': '0.5344'}
# EarlyStopping counter: 7 out of 10
# Recommendation EP_train:37: 100% 1047/1047 [00:21<00:00, 48.88it/s]
# {'epoch': 37, 'rec_loss': '0.5064'}
# Recommendation EP_test:37: 100% 24/24 [00:00<00:00, 61.57it/s]
# {'Epoch': 37, 'HIT@1': '0.3714', 'NDCG@1': '0.3714', 'HIT@5': '0.7248', 'NDCG@5': '0.5602', 'HIT@10': '0.8217', 'NDCG@10': '0.5917', 'MRR': '0.5271'}
# EarlyStopping counter: 8 out of 10
# Recommendation EP_train:38: 100% 1047/1047 [00:22<00:00, 46.95it/s]
# {'epoch': 38, 'rec_loss': '0.5054'}
# Recommendation EP_test:38: 100% 24/24 [00:00<00:00, 61.69it/s]
# {'Epoch': 38, 'HIT@1': '0.3780', 'NDCG@1': '0.3780', 'HIT@5': '0.7248', 'NDCG@5': '0.5631', 'HIT@10': '0.8250', 'NDCG@10': '0.5959', 'MRR': '0.5314'}
# EarlyStopping counter: 9 out of 10
# Recommendation EP_train:39: 100% 1047/1047 [00:22<00:00, 47.08it/s]
# {'epoch': 39, 'rec_loss': '0.5046'}
# Recommendation EP_test:39: 100% 24/24 [00:00<00:00, 61.99it/s]
# {'Epoch': 39, 'HIT@1': '0.3770', 'NDCG@1': '0.3770', 'HIT@5': '0.7224', 'NDCG@5': '0.5622', 'HIT@10': '0.8272', 'NDCG@10': '0.5962', 'MRR': '0.5312'}
# EarlyStopping counter: 10 out of 10
# Early stopping
# ---------------Sample 99 results---------------
# /content/FMLP-Rec/main.py:107: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   trainer.model.load_state_dict(torch.load(args.checkpoint_path))
# Recommendation EP_test:0: 100% 24/24 [00:00<00:00, 62.85it/s]
# {'Epoch': 0, 'HIT@1': '0.3581', 'NDCG@1': '0.3581', 'HIT@5': '0.6959', 'NDCG@5': '0.5381', 'HIT@10': '0.8015', 'NDCG@10': '0.5724', 'MRR': '0.5089'}
# FMLPRec-ML-1M-Feb-21-2025_12-56-17
# {'Epoch': 0, 'HIT@1': '0.3581', 'NDCG@1': '0.3581', 'HIT@5': '0.6959', 'NDCG@5': '0.5381', 'HIT@10': '0.8015', 'NDCG@10': '0.5724', 'MRR': '0.5089'}

# %% [markdown]
# Results for ML-1M Dataset: (5 minimum)
#
# * HR@1: 0.3430
# * HR@5: 0.6897
# * NDCG@5: 0.5292
# * HR@10: 0.7997
# * NDCG@10: 0.5650
# * MRR: 0.4995

# %% [markdown]
# Results for ML-1M Dataset: (no minimum)
#
# * HR@1: 0.3581
# * HR@5: 0.6959
# * NDCG@5: 0.5381
# * HR@10: 0.8015
# * NDCG@10: 0.5724
# * MRR: 0.5089
